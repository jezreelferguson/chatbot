# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
# Out:
# Running cells with 'venv (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/anokye-j-a-ferguson/Desktop/github/Churchmanager-ai/venv/bin/python -m pip install ipykernel -U --force-reinstall'
